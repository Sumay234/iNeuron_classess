# %%
import pandas as pd
import requests

# %%
from bs4 import BeautifulSoup

# %%
url="https://www.flipkart.com/search?q=mobile%20under%2070000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
r=requests.get(url)

# %%
soup=BeautifulSoup(r.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
np=soup.find("a",class_="_1LKTO3").get("href")

# %%
np
# Out:
# '/search?q=mobile+under+70000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2'

# %%
cmp="https://www.flipkart.com"+np

# %%
cmp
# Out:
# 'https://www.flipkart.com/search?q=mobile+under+70000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2'

# %%
url=cmp

# %%
r=requests.get(url)

# %%
soup=BeautifulSoup(r.text."lxml")
