# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\win11\Downloads\test.csv")

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df["Survived"] = df["SibSp"] + df["Parch"]

# %%
df.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         1
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         2

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Survived         0
# dtype: int64

# %%
df.dropna()
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# ..           ...     ...                                                ...
# 404         1296       1                       Frauenthal, Mr. Isaac Gerald
# 405         1297       2       Nourney, Mr. Alfred (Baron von Drachstedt")"
# 407         1299       1                         Widener, Mr. George Dunton
# 411         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
#
# ...

# %%
df.dropna(axis=1)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex  SibSp  Parch              Ticket Embarked  Survived
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Survived         0
# dtype: int64

# %%
# suppose if we want drop a a column whose not null value is less than 400
df.dropna(axis=1 , thresh=350)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex  SibSp  Parch              Ticket      Fare Embarked  Survived
# ...

# %%
# how = "all" means it will chech if all are null vale
df.dropna(axis=1,how="all")
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df.fillna(value="sumay")
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex    Age  SibSp  Parch              Ticket     Fare  Cabin Embarked  \
# ...

# %%
# suppose if we want to put null value on average of age --
df.fillna(value = df["Age"].mean())
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare     Cabin  \
# ...

# %%
df.groupby("Survived").describe()
# Out:
#          PassengerId                                                    \
#                count         mean         std     min      25%     50%
# Survived
# 0              253.0  1100.438735  119.039714   892.0   997.00  1101.0
# 1               74.0  1090.243243  130.907874   893.0   978.25  1099.5
# 2               57.0  1115.824561  113.495771   896.0  1051.00  1110.0
# 3               14.0  1109.571429  127.394429   924.0   997.25  1139.0
# 4                7.0  1079.428571  147.648069   916.0   990.00  1034.0
# 5                3.0   951.000000    8.717798   945.0   946.00   947.0
# 6                4.0  1122.250000  102.255807  1046.0  1061.00  1086.0
# 7                2.0  1031.500000    0.707107  1031.0  1031.25  1031.5
# 10               4.0  1205.750000   84.413170  1080.0  1195.50  1243.0
#
#                           Pclass            ... Parch        Fare              \
#               75%     max  count      mean  ...   75%  max  count        mean
# ...

# %%
df.groupby("Survived").describe()["PassengerId"]
# Out:
#           count         mean         std     min      25%     50%      75%  \
# Survived
# 0         253.0  1100.438735  119.039714   892.0   997.00  1101.0  1205.00
# 1          74.0  1090.243243  130.907874   893.0   978.25  1099.5  1197.75
# 2          57.0  1115.824561  113.495771   896.0  1051.00  1110.0  1200.00
# 3          14.0  1109.571429  127.394429   924.0   997.25  1139.0  1213.00
# 4           7.0  1079.428571  147.648069   916.0   990.00  1034.0  1170.00
# 5           3.0   951.000000    8.717798   945.0   946.00   947.0   954.00
# 6           4.0  1122.250000  102.255807  1046.0  1061.00  1086.0  1147.25
# 7           2.0  1031.500000    0.707107  1031.0  1031.25  1031.5  1031.75
# 10          4.0  1205.750000   84.413170  1080.0  1195.50  1243.0  1253.25
#
#              max
# Survived
# 0         1308.0
# 1         1303.0
# 2         1309.0
# 3         1277.0
# 4         1286.0
# 5          961.0
# 6         1271.0
# 7         1032.0
# 10        1257.0

# %%
df.groupby("Survived").describe()["PassengerId"].T
# Out:
# Survived           0            1            2            3            4   \
# count      253.000000    74.000000    57.000000    14.000000     7.000000
# mean      1100.438735  1090.243243  1115.824561  1109.571429  1079.428571
# std        119.039714   130.907874   113.495771   127.394429   147.648069
# min        892.000000   893.000000   896.000000   924.000000   916.000000
# 25%        997.000000   978.250000  1051.000000   997.250000   990.000000
# 50%       1101.000000  1099.500000  1110.000000  1139.000000  1034.000000
# 75%       1205.000000  1197.750000  1200.000000  1213.000000  1170.000000
# max       1308.000000  1303.000000  1309.000000  1277.000000  1286.000000
#
# Survived          5            6            7           10
# count       3.000000     4.000000     2.000000     4.00000
# mean      951.000000  1122.250000  1031.500000  1205.75000
# std         8.717798   102.255807     0.707107    84.41317
# min       945.000000  1046.000000  1031.000000  1080.00000
# ...

# %%
df.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked  Survived
# 0      0  330911  7.8292   NaN        Q         0
# 1      0  363272  7.0000   NaN        S         1
# 2      0  240276  9.6875   NaN        Q         0

# %%
df[:]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df.iloc[:, 3]
# Out:
# 0        male
# 1      female
# 2        male
# 3        male
# 4      female
#         ...
# 413      male
# 414    female
# 415      male
# 416      male
# 417      male
# Name: Sex, Length: 418, dtype: object

# %%
df.iloc[ :,[3,4]]
# Out:
#         Sex   Age
# 0      male  34.5
# 1    female  47.0
# 2      male  62.0
# 3      male  27.0
# 4    female  22.0
# ..      ...   ...
# 413    male   NaN
# 414  female  39.0
# 415    male  38.5
# 416    male   NaN
# 417    male   NaN
#
# [418 rows x 2 columns]

# %%
iloc - always take a deaufualt one or inbuild one
loc  - always take a name one

# %%
df.head(6)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         1
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         2
# ...

# %%
# suppose if we want get only name and age of 5 and 6 position not the index one
# than we will use loc 

df.loc[[4,5], ["Name","Age"]]
# Out:
#                                            Name   Age
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# 5                    Svensson, Mr. Johan Cervin  14.0

# %%
df.loc[[5]]
# Out:
#    PassengerId  Pclass                        Name   Sex   Age  SibSp  Parch  \
# 5          897       3  Svensson, Mr. Johan Cervin  male  14.0      0      0
#
#   Ticket   Fare Cabin Embarked  Survived
# 5   7538  9.225   NaN        S         0

# %%
df.loc[[2,6],["Sex","Name","Age"]]
# Out:
#       Sex                       Name   Age
# 2    male  Myles, Mr. Thomas Francis  62.0
# 6  female       Connolly, Miss. Kate  30.0

# %%
# we can get the same result by using iloc--
df.iloc[[2,3],[2,3,4]]
# Out:
#                         Name   Sex   Age
# 2  Myles, Mr. Thomas Francis  male  62.0
# 3           Wirz, Mr. Albert  male  27.0

# %%
df.iloc[:,[2,3]]
# Out:
#                                              Name     Sex
# 0                                Kelly, Mr. James    male
# 1                Wilkes, Mrs. James (Ellen Needs)  female
# 2                       Myles, Mr. Thomas Francis    male
# 3                                Wirz, Mr. Albert    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..                                            ...     ...
# 413                            Spector, Mr. Woolf    male
# 414                  Oliva y Ocana, Dona. Fermina  female
# 415                  Saether, Mr. Simon Sivertsen    male
# 416                           Ware, Mr. Frederick    male
# 417                      Peter, Master. Michael J    male
#
# [418 rows x 2 columns]

# %%
df2=df.loc[:6,["Sex","Age","Pclass"]]

# %%
df2
# Out:
#       Sex   Age  Pclass
# 0    male  34.5       3
# 1  female  47.0       3
# 2    male  62.0       2
# 3    male  27.0       3
# 4  female  22.0       3
# 5    male  14.0       3
# 6  female  30.0       3

# %%
df2.set_index("Age")
# Out:
#          Sex  Pclass
# Age
# 34.5    male       3
# 47.0  female       3
# 62.0    male       2
# 27.0    male       3
# 22.0  female       3
# 14.0    male       3
# 30.0  female       3

# %%
df3=df.loc[:6,["Age","Sex","Pclass"]]

# %%
df3
# Out:
#     Age     Sex  Pclass
# 0  34.5    male       3
# 1  47.0  female       3
# 2  62.0    male       2
# 3  27.0    male       3
# 4  22.0  female       3
# 5  14.0    male       3
# 6  30.0  female       3

# %%
# to rename the column----
df3 = df3.rename(columns={"Age":"Age_1","Sex":"Sex_1","Pclass":"Pclass_1"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [88], in <cell line: 2>()
#       1 # to rename the column----
# ----> 2 df3 = df3.rename(columns={"Age":"Age_1","Sex":"Sex_1","Pclass":"Pclass_1"})
#
# AttributeError: 'NoneType' object has no attribute 'rename'

# %%
df3 = df3.rename(columns={"Age":"Age_1","Sex":"Sex_1","Pclass":"Pclass_1"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [89], in <cell line: 1>()
# ----> 1 df3 = df3.rename(columns={"Age":"Age_1","Sex":"Sex_1","Pclass":"Pclass_1"})
#
# AttributeError: 'NoneType' object has no attribute 'rename'

# %%
df2
# Out:
#       Sex   Age  Pclass
# 0    male  34.5       3
# 1  female  47.0       3
# 2    male  62.0       2
# 3    male  27.0       3
# 4  female  22.0       3
# 5    male  14.0       3
# 6  female  30.0       3

# %%
# i prefer to use merge instead of join
