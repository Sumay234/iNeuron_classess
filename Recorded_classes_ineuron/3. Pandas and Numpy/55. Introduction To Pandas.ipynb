# %% [markdown]
# ## Cassandra

# %%
Why cassandra (NoSQL)

1) Scalability --> we can increase our space or memory capacity
2) High availabilty -->
3) decentralise --> no single failurer
4) scalable -->
# Out:
#   Input In [3]
#     Why cassandra (NoSQL)
#         ^
# SyntaxError: invalid syntax

# %%
SQL is known as Vertically Scalabel system whereas 
Cassandra is known as Horizontally scalabel system
# Out:
#   Input In [2]
#     SQL is known as Vertically Scalabel system whereas
#                  ^
# SyntaxError: invalid syntax

# %%
! pip install cassandra-driver
# Out:
# ^C

# %%
pip install cassandra-driver
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Introduction To Pandas

# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\win11\Downloads\ohana-api-master\data\sample-csv\locations.csv").head()
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                    wheelchair
# 2   3                1                                           NaN
# 3   4                1                                    wheelchair
# 4   5                1                                    wheelchair
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
# 2  Offers supportive counseling services to San M...   NaN
# 3  Provides supervised visitation services and a ...   NaN
# 4  Provides fixed 8% short term loans to eligible...   NaN
#
# ...

# %%
pd.read_csv(r"C:\Users\win11\Downloads\ohana-api-master\data\sample-csv\taxonomy.csv")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
data=r"C:\Users\win11\Downloads\ohana-api-master\data\sample-csv\taxonomy.csv"

# %%
pd.read_csv(data,header = None)
# Out:
#                0                             1          2  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         3
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
# to change the header name

pd.read_csv(data,names=["abc","def","ghi","jkl"])
# Out:
#              abc                           def        ghi  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                       jkl
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
# to give more columns name

pd.read_csv(data,names=["abc","def","ghi","jkl","gghg","wygy"])
# Out:
#              abc                           def        ghi  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                       jkl  gghg  wygy
# 0             parent_name   NaN   NaN
# 1                     NaN   NaN   NaN
# 2               Emergency   NaN   NaN
# 3               Emergency   NaN   NaN
# 4          Emergency Cash   NaN   NaN
# ...

# %%
# to skip or delete row no
pd.read_csv(data,skiprows=[1,3]).head(5)
# Out:
#   taxonomy_id                     name parent_id     parent_name
# 0      101-01        Disaster Response       101       Emergency
# 1   101-02-01        Help Pay for Food    101-02  Emergency Cash
# 2   101-02-02  Help Pay for Healthcare    101-02  Emergency Cash
# 3   101-02-03     Help Pay for Housing    101-02  Emergency Cash
# 4   101-02-04         Help Pay for Gas    101-02  Emergency Cash

# %%
df=pd.read_csv(r"C:\Users\win11\Downloads\ohana-api-master\data\sample-csv\services.csv")

# %%
df.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df["name"]
# Out:
# 0          Fair Oaks Adult Activity Center
# 1         Second Career Employment Program
# 2                   Senior Peer Counseling
# 3                 Family Visitation Center
# 4        Economic Self-Sufficiency Program
# 5     Little House Recreational Activities
# 6         Rosener House Adult Day Services
# 7           Meals on Wheels - South County
# 8                         Fair Oaks Branch
# 9                             Main Library
# 10                         Schaberg Branch
# 11                            Project Read
# 12                   Redwood Shores Branch
# 13                      Redwood City Corps
# 14             Adult Rehabilitation Center
# 15                         Sunnyvale Corps
# 16       South San Francisco Citadel Corps
# 17                           Project Smile
# 18           San Mateo Free Medical Clinic
# 19               Service with blank fields
# 20         Service for Admin Test Location
# 21                         Passport Photos
# ...

# %%
a=df["name"]

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df[["name",'location_id', 'program_id']]
# Out:
#                                     name  location_id  program_id
# 0        Fair Oaks Adult Activity Center            1         NaN
# 1       Second Career Employment Program            2         NaN
# 2                 Senior Peer Counseling            3         NaN
# 3               Family Visitation Center            4         NaN
# 4      Economic Self-Sufficiency Program            5         NaN
# 5   Little House Recreational Activities            6         NaN
# 6       Rosener House Adult Day Services            7         NaN
# 7         Meals on Wheels - South County            8         NaN
# 8                       Fair Oaks Branch            9         NaN
# 9                           Main Library           10         NaN
# 10                       Schaberg Branch           11         NaN
# 11                          Project Read           12         NaN
# 12                 Redwood Shores Branch           13         NaN
# ...

# %%
a1=df[["name",'location_id', 'program_id']]

# %%
type(a1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["name"])
# Out:
# pandas.core.series.Series

# %%
type(df[["name"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## using excel sheet

# %%
data=r"C:\Users\win11\Downloads\sample-excel-master\sample-excel-master\LUSID Excel - Manage Orders.xlsx"

# %%
df=pd.read_excel(data)

# %%
df.head(2)
# Out:
#    Unnamed: 0                                   Unnamed: 1 Unnamed: 2  \
# 0         NaN  This sheet allows you to manage executions:        NaN
# 1         NaN                           1. List executions        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 0        NaN         NaN         NaN         NaN         NaN         NaN
# 1        NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN

# %%
# to import specific sheet abailable in the excel sheet

pd.read_excel(data,sheet_name="Allocations").head(4)
# Out:
#    Unnamed: 0                                    Unnamed: 1 Unnamed: 2  \
# 0         NaN  This sheet allows you to manage Allocations:        NaN
# 1         NaN                            1. ListAllocations        NaN
# 2         NaN                              2. GetAllocation        NaN
# 3         NaN                          3. UpsertAllocations        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        NaN  ...         NaN         NaN         NaN         NaN         NaN
# ...

# %%
# to know the all sheet available in excel sheet --

df=pd.ExcelFile(data)
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in df.sheet_names:
    a=pd.read_excel(data, sheet_name=i)

# %%
a.head(4)
# Out:
#    Unnamed: 0                               Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0         NaN  This sheet allows you to manage Blocks:        NaN        NaN
# 1         NaN                            1. ListBlocks        NaN        NaN
# 2         NaN                              2. GetBlock        NaN        NaN
# 3         NaN                          3. UpsertBlocks        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %% [markdown]
# ### how to import dataset from URL

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\lib\urllib\request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1345 try:
# -> 1346     h.request(req.get_method(), req.selector, req.data, headers,
#    1347               encode_chunked=req.has_header('Transfer-encoding'))
#    1348 except OSError as err: # timeout error
#
# File ~\anaconda3\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...
