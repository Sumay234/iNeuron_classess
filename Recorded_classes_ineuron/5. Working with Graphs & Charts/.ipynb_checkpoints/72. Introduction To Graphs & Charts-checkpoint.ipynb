# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.DataFrame(np.random.randn(1000), columns=["data"] )

# %%
df
# Out:
#          data
# 0    0.136474
# 1    0.349276
# 2   -0.447137
# 3    0.140631
# 4   -0.913865
# ..        ...
# 995 -0.383357
# 996 -0.589221
# 997  0.727187
# 998  1.573491
# 999 -0.042039
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.randn(1000),columns=['data'],index=pd.date_range("2022/01/24",periods=1000))

# %%
df
# Out:
#                 data
# 2022-01-24 -0.011946
# 2022-01-25  2.224309
# 2022-01-26 -0.413083
# 2022-01-27  0.670691
# 2022-01-28 -0.976522
# ...              ...
# 2024-10-15  0.792430
# 2024-10-16 -0.696703
# 2024-10-17  0.462660
# 2024-10-18 -1.049323
# 2024-10-19 -0.444802
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df1=pd.read_csv("H:\dataset_csv\Iris.csv").head(2)

# %%
df1.head(4)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa

# %%
df=pd.read_csv("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv")

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df.value_counts()
# Out:
# sepal_length  sepal_width  petal_length  petal_width  species
# 4.9           3.1          1.5           0.1          setosa        3
# 5.8           2.7          5.1           1.9          virginica     2
#               4.0          1.2           0.2          setosa        1
# 5.9           3.0          4.2           1.5          versicolor    1
# 6.2           3.4          5.4           2.3          virginica     1
#                                                                    ..
# 5.5           2.3          4.0           1.3          versicolor    1
#               2.4          3.7           1.0          versicolor    1
#                            3.8           1.1          versicolor    1
#               2.5          4.0           1.3          versicolor    1
# 7.9           3.8          6.4           2.0          virginica     1
# Length: 147, dtype: int64

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="bar",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind="bar",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[:1].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:9].plot(kind="barh",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="hist",figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["sepal_length"].plot(kind="hist",figsize=(10,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["sepal_length"].value_counts()
# Out:
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: sepal_length, dtype: int64

# %%
df.hist(figsize=(20,10),color="r")
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.plot(kind="box",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="box",vert=False,figsize=(20,10),color="r")
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="area",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="area",figsize=(20,10),stacked=False)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x="sepal_length",y="petal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot.scatter(x="sepal_length",y="petal_length",c="sepal_width",figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x="sepal_length",y="petal_length",c="sepal_width",figsize=(10,5),s=100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x="sepal_length",y="petal_length",gridsize=15)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1=df.drop(columns="species").iloc[0]

# %%
df1
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df1.plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='0'>

# %%
# !pip install plotly # to install plotly graph--

# %%
# !pip install cufflinks # to install cufflinks--
# Out:
# ...
#      -------------------------------------- 81.7/81.7 kB 199.2 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68736 sha256=64b0ddb4822a99b23983212ff54ef57559259c6c9e862e3a3930fbed3d787bb5
#   Stored in directory: c:\users\win11\appdata\local\pip\cache\wheels\32\f7\bd\3b5f431b9a740489de249dad87142f8ee000b7c6b6e8e58d54
# Successfully built cufflinks
# ...

# %%
# !pip install chart_studio
# Out:
# ...
#      -------------------------------------- 64.4/64.4 kB 144.5 kB/s eta 0:00:00
# ...

# %%
import cufflinks as cf
cf.go_offline()    # its is a offline version of plotly to work efficiently--
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.iplot()
# Out:
# <div>                            <div id="26053c38-6da0-4ad1-b1a6-66d82904a00f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind="hist")
# Out:
# <div>                            <div id="450b57c9-7fa1-4c2d-a3c4-f1f945e5e9a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x="sepal_length",y="petal_length",mode="markers")
# Out:
# <div>                            <div id="953d8da1-6cb8-444b-af67-d7d441c35cd1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind="scatter",mode="markers")
# Out:
# <div>                            <div id="13ca3b47-7861-48be-9273-c0e8821fce1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind="bubble",x="sepal_length",y="petal_length",size="sepal_width")
# Out:
# <div>                            <div id="d443cc7a-3c1e-4fa3-a5ef-b9c592bb8208" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="bc605b53-5dae-4b5e-ab0f-fe537fad3b0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind="scatter3d",x="sepal_length",y="petal_length",z="sepal_width")
# Out:
# <div>                            <div id="b7ff3dd0-e643-4a92-93b5-b0e6090d5619" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind="scatter3d",x="sepal_length",y="petal_length",z="sepal_width")
# Out:
# <div>                            <div id="f9a38a00-2f64-44b2-871c-e34f8893914f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
